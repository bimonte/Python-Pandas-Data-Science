# %%
import os

# %%
oRawFile = open('Bases/201904.csv')

# %%
oRawFile.readline()
# Out:
# 'Order ID,Product,Quantity Ordered,Price Each,Order Date,Purchase Address\n'

# %%
oRawFile.readline()
# Out:
# '176558,USB-C Charging Cable,2,11.95,04/19/19 08:46,"917 1st St, Dallas, TX 75001"\n'

# %%
oRawFile.readline()
# Out:
# ',,,,,\n'

# %%
oRawFile.readline()
# Out:
# '176559,Bose SoundSport Headphones,1,99.99,04/07/19 22:30,"682 Chestnut St, Boston, MA 02215"\n'

# %%
oRawFile.readline()
# Out:
# '176560,Google Phone,1,600,04/12/19 14:38,"669 Spruce St, Los Angeles, CA 90001"\n'

# %%
oRawFile.readline()
# Out:
# '176560,Wired Headphones,1,11.99,04/12/19 14:38,"669 Spruce St, Los Angeles, CA 90001"\n'

# %%
for i in range(10):

    print(oRawFile.readline())
    
oRawFile.close()
# Out:
# 176561,Wired Headphones,1,11.99,04/30/19 09:27,"333 8th St, Los Angeles, CA 90001"
#
# 176562,USB-C Charging Cable,1,11.95,04/29/19 13:03,"381 Wilson St, San Francisco, CA 94016"
#
# 176563,Bose SoundSport Headphones,1,99.99,04/02/19 07:46,"668 Center St, Seattle, WA 98101"
#
# 176564,USB-C Charging Cable,1,11.95,04/12/19 10:58,"790 Ridge St, Atlanta, GA 30301"
#
# 176565,Macbook Pro Laptop,1,1700,04/24/19 10:38,"915 Willow St, San Francisco, CA 94016"
#
# 176566,Wired Headphones,1,11.99,04/08/19 14:05,"83 7th St, Boston, MA 02215"
#
# 176567,Google Phone,1,600,04/18/19 17:18,"444 7th St, Los Angeles, CA 90001"
#
# 176568,Lightning Charging Cable,1,14.95,04/15/19 12:18,"438 Elm St, Seattle, WA 98101"
#
# 176569,27in 4K Gaming Monitor,1,389.99,04/16/19 19:23,"657 Hill St, Dallas, TX 75001"
#
# 176570,AA Batteries (4-pack),1,3.84,04/22/19 15:09,"186 12th St, Dallas, TX 75001"

# %%
import pandas as pd

# %%
DF = pd.read_csv('Bases/201904.csv')
DF
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
VENDAS = pd.DataFrame()

# %%
for file in os.listdir('Bases'):
    
    #print(file)
    
    DF = pd.read_csv('Bases\\' + file)
    DF['Origem'] = file.split('.')[0]
    
    VENDAS = VENDAS.append(DF)

# %%
VENDAS = VENDAS.drop_duplicates()
VENDAS
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       141234                      iPhone                1        700
# 1       141235    Lightning Charging Cable                1      14.95
# 2       141236            Wired Headphones                2      11.99
# 3       141237            27in FHD Monitor                1     149.99
# 4       141238            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 25112   319666    Lightning Charging Cable                1      14.95
# 25113   319667       AA Batteries (4-pack)                2       3.84
# 25114   319668             Vareebadd Phone                1        400
# 25115   319669            Wired Headphones                1      11.99
# 25116   319670  Bose SoundSport Headphones                1      99.99
#
#            Order Date                        Purchase Address  Origem
# ...

# %%
VENDAS = VENDAS.reset_index(drop = True) # drop = True - eliminar o índice antigo
VENDAS
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        141234                      iPhone                1        700
# 1        141235    Lightning Charging Cable                1      14.95
# 2        141236            Wired Headphones                2      11.99
# 3        141237            27in FHD Monitor                1     149.99
# 4        141238            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 185705   319666    Lightning Charging Cable                1      14.95
# 185706   319667       AA Batteries (4-pack)                2       3.84
# 185707   319668             Vareebadd Phone                1        400
# 185708   319669            Wired Headphones                1      11.99
# 185709   319670  Bose SoundSport Headphones                1      99.99
#
#             Order Date                        Purchase Address  Origem
# ...

# %%
VENDAS.head(20)
# Out:
#    Order ID                     Product Quantity Ordered Price Each  \
# 0    141234                      iPhone                1        700
# 1    141235    Lightning Charging Cable                1      14.95
# 2    141236            Wired Headphones                2      11.99
# 3    141237            27in FHD Monitor                1     149.99
# 4    141238            Wired Headphones                1      11.99
# 5    141239      AAA Batteries (4-pack)                1       2.99
# 6    141240      27in 4K Gaming Monitor                1     389.99
# 7    141241        USB-C Charging Cable                1      11.95
# 8    141242  Bose SoundSport Headphones                1      99.99
# 9    141243    Apple Airpods Headphones                1        150
# 10   141244    Apple Airpods Headphones                1        150
# 11   141245          Macbook Pro Laptop                1       1700
# 12   141246      AAA Batteries (4-pack)                3       2.99
# ...

# %%
VENDAS.to_csv('VendasTT2019.csv', index = False)

# %% [markdown]
# ## 01. Qual foi o melhor mês de vendas? Quanto foi vendido neste mês?

# %% [markdown]
# ### Adicionar o mês da venda

# %%
VENDAS['Order Date'].str[:2]
VENDAS['Mes'] = VENDAS['Order Date'].str[:2]
VENDAS
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        141234                      iPhone                1        700
# 1        141235    Lightning Charging Cable                1      14.95
# 2        141236            Wired Headphones                2      11.99
# 3        141237            27in FHD Monitor                1     149.99
# 4        141238            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 185705   319666    Lightning Charging Cable                1      14.95
# 185706   319667       AA Batteries (4-pack)                2       3.84
# 185707   319668             Vareebadd Phone                1        400
# 185708   319669            Wired Headphones                1      11.99
# 185709   319670  Bose SoundSport Headphones                1      99.99
#
#             Order Date                        Purchase Address  Origem Mes
# ...

# %%
VENDAS['Mes'] = VENDAS['Mes'].astype('int')
VENDAS
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-58d4b4f76b39> in <module>
# ----> 1 VENDAS['Mes'] = VENDAS['Mes'].astype('int')
#       2 VENDAS
#
# c:\users\bimonte\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# c:\users\bimonte\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
# ...

# %%
VENDAS.head(50)
# Out:
#    Order ID                     Product Quantity Ordered Price Each  \
# 0    141234                      iPhone                1        700
# 1    141235    Lightning Charging Cable                1      14.95
# 2    141236            Wired Headphones                2      11.99
# 3    141237            27in FHD Monitor                1     149.99
# 4    141238            Wired Headphones                1      11.99
# 5    141239      AAA Batteries (4-pack)                1       2.99
# 6    141240      27in 4K Gaming Monitor                1     389.99
# 7    141241        USB-C Charging Cable                1      11.95
# 8    141242  Bose SoundSport Headphones                1      99.99
# 9    141243    Apple Airpods Headphones                1        150
# 10   141244    Apple Airpods Headphones                1        150
# 11   141245          Macbook Pro Laptop                1       1700
# 12   141246      AAA Batteries (4-pack)                3       2.99
# ...

# %%
VENDAS[VENDAS.isna().any(axis = 'columns')] # columns - para retornar True se qualquer coluna também True
# Out:
#        Order ID Product Quantity Ordered Price Each Order Date  \
# 664         NaN     NaN              NaN        NaN        NaN
# 9748        NaN     NaN              NaN        NaN        NaN
# 22687       NaN     NaN              NaN        NaN        NaN
# 36775       NaN     NaN              NaN        NaN        NaN
# 55101       NaN     NaN              NaN        NaN        NaN
# 71924       NaN     NaN              NaN        NaN        NaN
# 85323       NaN     NaN              NaN        NaN        NaN
# 99710       NaN     NaN              NaN        NaN        NaN
# 111537      NaN     NaN              NaN        NaN        NaN
# 123235      NaN     NaN              NaN        NaN        NaN
# 143275      NaN     NaN              NaN        NaN        NaN
# 161023      NaN     NaN              NaN        NaN        NaN
#
#        Purchase Address  Origem  Mes
# 664                 NaN  201901  NaN
# 9748                NaN  201902  NaN
# ...

# %%
VENDAS = VENDAS.dropna()

# %%
VENDAS['Mes'] = VENDAS['Mes'].astype('int')
VENDAS
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-58d4b4f76b39> in <module>
# ----> 1 VENDAS['Mes'] = VENDAS['Mes'].astype('int')
#       2 VENDAS
#
# c:\users\bimonte\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# c:\users\bimonte\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
# ...

# %%
VENDAS[VENDAS['Mes'] == 'Or']
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 1069    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 11147   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 22075   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 37291   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 56004   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 71743   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 85896   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 99610   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 113012  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 123473  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 144369  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 161013  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#         Purchase Address  Origem Mes
# 1069    Purchase Address  201901  Or
# ...

# %%
VENDAS = VENDAS[VENDAS['Mes'] != 'Or']

# %%
VENDAS['Mes'] = VENDAS['Mes'].astype('int')
VENDAS
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        141234                      iPhone                1        700
# 1        141235    Lightning Charging Cable                1      14.95
# 2        141236            Wired Headphones                2      11.99
# 3        141237            27in FHD Monitor                1     149.99
# 4        141238            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 185705   319666    Lightning Charging Cable                1      14.95
# 185706   319667       AA Batteries (4-pack)                2       3.84
# 185707   319668             Vareebadd Phone                1        400
# 185708   319669            Wired Headphones                1      11.99
# 185709   319670  Bose SoundSport Headphones                1      99.99
#
#             Order Date                        Purchase Address  Origem  Mes
# ...

# %% [markdown]
# ### Adicionar o faturamento das vendas

# %%
VENDAS['Faturamento'] = VENDAS['Quantity Ordered'] * VENDAS['Price Each']
VENDAS
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\bimonte\appdata\local\programs\python\python38\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     148     try:
# --> 149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
#
# c:\users\bimonte\appdata\local\programs\python\python38\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# c:\users\bimonte\appdata\local\programs\python\python38\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#
# ...

# %%
VENDAS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185686 entries, 0 to 185709
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185686 non-null  object
#  1   Product           185686 non-null  object
#  2   Quantity Ordered  185686 non-null  object
#  3   Price Each        185686 non-null  object
#  4   Order Date        185686 non-null  object
#  5   Purchase Address  185686 non-null  object
#  6   Origem            185686 non-null  object
#  7   Mes               185686 non-null  int32
# dtypes: int32(1), object(7)
# memory usage: 12.0+ MB

# %%
VENDAS['Quantity Ordered'] = pd.to_numeric(VENDAS['Quantity Ordered'])
VENDAS['Price Each'] = pd.to_numeric(VENDAS['Price Each'])
VENDAS
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        141234                      iPhone                 1      700.00
# 1        141235    Lightning Charging Cable                 1       14.95
# 2        141236            Wired Headphones                 2       11.99
# 3        141237            27in FHD Monitor                 1      149.99
# 4        141238            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 185705   319666    Lightning Charging Cable                 1       14.95
# 185706   319667       AA Batteries (4-pack)                 2        3.84
# 185707   319668             Vareebadd Phone                 1      400.00
# 185708   319669            Wired Headphones                 1       11.99
# 185709   319670  Bose SoundSport Headphones                 1       99.99
#
#             Order Date                        Purchase Address  Origem  Mes
# ...

# %%
VENDAS['Faturamento'] = VENDAS['Quantity Ordered'] * VENDAS['Price Each']
VENDAS
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        141234                      iPhone                 1      700.00
# 1        141235    Lightning Charging Cable                 1       14.95
# 2        141236            Wired Headphones                 2       11.99
# 3        141237            27in FHD Monitor                 1      149.99
# 4        141238            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 185705   319666    Lightning Charging Cable                 1       14.95
# 185706   319667       AA Batteries (4-pack)                 2        3.84
# 185707   319668             Vareebadd Phone                 1      400.00
# 185708   319669            Wired Headphones                 1       11.99
# 185709   319670  Bose SoundSport Headphones                 1       99.99
#
#             Order Date                        Purchase Address  Origem  Mes  \
# ...

# %%
VENDAS.groupby('Mes').sum()
# Out:
#      Quantity Ordered    Price Each   Faturamento
# Mes
# 1               10893  1.810925e+06  1.821413e+06
# 2               13431  2.186940e+06  2.200078e+06
# 3               16979  2.789085e+06  2.804973e+06
# 4               20536  3.366219e+06  3.389218e+06
# 5               18653  3.133135e+06  3.150616e+06
# 6               15234  2.560504e+06  2.576280e+06
# 7               16054  2.631225e+06  2.646461e+06
# 8               13429  2.226964e+06  2.241083e+06
# 9               13091  2.081898e+06  2.094466e+06
# 10              22669  3.713609e+06  3.734778e+06
# 11              19769  3.178873e+06  3.197875e+06
# 12              28074  4.583268e+06  4.608296e+06

# %%
VENDAS.groupby('Mes').sum()['Faturamento']
# Out:
# Mes
# 1     1.821413e+06
# 2     2.200078e+06
# 3     2.804973e+06
# 4     3.389218e+06
# 5     3.150616e+06
# 6     2.576280e+06
# 7     2.646461e+06
# 8     2.241083e+06
# 9     2.094466e+06
# 10    3.734778e+06
# 11    3.197875e+06
# 12    4.608296e+06
# Name: Faturamento, dtype: float64

# %%
VENDAS.groupby('Mes').sum()['Faturamento'].apply(lambda _x: f'$ {_x:1.2f}')
# Out:
# Mes
# 1     $ 1821413.16
# 2     $ 2200078.08
# 3     $ 2804973.35
# 4     $ 3389217.98
# 5     $ 3150616.23
# 6     $ 2576280.15
# 7     $ 2646461.32
# 8     $ 2241083.37
# 9     $ 2094465.69
# 10    $ 3734777.86
# 11    $ 3197875.05
# 12    $ 4608295.70
# Name: Faturamento, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
xData = range(1, 13) # Meses
yData = VENDAS.groupby('Mes').sum()['Faturamento']

plt.bar(xData, yData)

plt.xticks(xData)
plt.title('Faturamento Mensal')
plt.ylabel('Faturamento em $')
plt.xlabel('Mês')

plt.show()

# %% [markdown]
# #### Melhor mês dezembro, com $ 4608295.70

# %% [markdown]
# ## 02. Qual cidade teve o maior volume de vendas?

# %% [markdown]
# ### Adicionar a coluna Cidade

# %%
VENDAS['Purchase Address'].apply(lambda end: end.split(',')[1])
# Out:
# 0                 Boston
# 1               Portland
# 2          San Francisco
# 3            Los Angeles
# 4                 Austin
#                ...
# 185705     San Francisco
# 185706       Los Angeles
# 185707           Seattle
# 185708            Dallas
# 185709       Los Angeles
# Name: Purchase Address, Length: 185686, dtype: object

# %%
VENDAS['Cidade'] = VENDAS['Purchase Address'].apply(lambda end: end.split(',')[1])
VENDAS
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        141234                      iPhone                 1      700.00
# 1        141235    Lightning Charging Cable                 1       14.95
# 2        141236            Wired Headphones                 2       11.99
# 3        141237            27in FHD Monitor                 1      149.99
# 4        141238            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 185705   319666    Lightning Charging Cable                 1       14.95
# 185706   319667       AA Batteries (4-pack)                 2        3.84
# 185707   319668             Vareebadd Phone                 1      400.00
# 185708   319669            Wired Headphones                 1       11.99
# 185709   319670  Bose SoundSport Headphones                 1       99.99
#
#             Order Date                        Purchase Address  Origem  Mes  \
# ...

# %%
VENDAS['Purchase Address'].apply(lambda end: end.split(',')[1] + end.split(',')[2])
# Out:
# 0                 Boston MA 02215
# 1               Portland OR 97035
# 2          San Francisco CA 94016
# 3            Los Angeles CA 90001
# 4                 Austin TX 73301
#                    ...
# 185705     San Francisco CA 94016
# 185706       Los Angeles CA 90001
# 185707           Seattle WA 98101
# 185708            Dallas TX 75001
# 185709       Los Angeles CA 90001
# Name: Purchase Address, Length: 185686, dtype: object

# %%
VENDAS['Cidade'] = VENDAS['Purchase Address'].apply(lambda end: end.split(',')[1] + '-' + end.split(',')[2].split(' ')[1])
VENDAS
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        141234                      iPhone                 1      700.00
# 1        141235    Lightning Charging Cable                 1       14.95
# 2        141236            Wired Headphones                 2       11.99
# 3        141237            27in FHD Monitor                 1      149.99
# 4        141238            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 185705   319666    Lightning Charging Cable                 1       14.95
# 185706   319667       AA Batteries (4-pack)                 2        3.84
# 185707   319668             Vareebadd Phone                 1      400.00
# 185708   319669            Wired Headphones                 1       11.99
# 185709   319670  Bose SoundSport Headphones                 1       99.99
#
#             Order Date                        Purchase Address  Origem  Mes  \
# ...

# %%
VENDAS.groupby('Cidade').sum()['Faturamento'].apply(lambda _x: f'$ {_x:1.2f}')
# Out:
# Cidade
#  Atlanta-GA          $ 2794199.07
#  Austin-TX           $ 1818044.33
#  Boston-MA           $ 3658627.65
#  Dallas-TX           $ 2765373.96
#  Los Angeles-CA      $ 5448304.28
#  New York City-NY    $ 4661867.14
#  Portland-ME          $ 449321.38
#  Portland-OR         $ 1870010.56
#  San Francisco-CA    $ 8254743.55
#  Seattle-WA          $ 2745046.02
# Name: Faturamento, dtype: object

# %%
VENDAS['Cidade'].unique()
# Out:
# array([' Boston-MA', ' Portland-OR', ' San Francisco-CA',
#        ' Los Angeles-CA', ' Austin-TX', ' Atlanta-GA', ' Seattle-WA',
#        ' New York City-NY', ' Dallas-TX', ' Portland-ME'], dtype=object)

# %%
[cidade for cidade, df in VENDAS.groupby('Cidade')]
# Out:
# [' Atlanta-GA',
#  ' Austin-TX',
#  ' Boston-MA',
#  ' Dallas-TX',
#  ' Los Angeles-CA',
#  ' New York City-NY',
#  ' Portland-ME',
#  ' Portland-OR',
#  ' San Francisco-CA',
#  ' Seattle-WA']

# %%
xData = [cidade for cidade, df in VENDAS.groupby('Cidade')]
yData = VENDAS.groupby('Cidade').sum()['Faturamento']

plt.bar(xData, yData)

plt.xticks(xData, rotation = 'vertical')
plt.title('Faturamento por Cidade')
plt.ylabel('Faturamento em $')
plt.xlabel('Cidade')

plt.show()

# %% [markdown]
# #### San Francisco com $ 8254743.55

# %% [markdown]
# ## 03. Em quais horários é maior a probabilidade de receber pedidos de clientes pelos canais de venda?

# %% [markdown]
# ### Criar uma coluna Hora

# %%
VENDAS['Order Date'] = pd.to_datetime(VENDAS['Order Date'])
VENDAS
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        141234                      iPhone                 1      700.00
# 1        141235    Lightning Charging Cable                 1       14.95
# 2        141236            Wired Headphones                 2       11.99
# 3        141237            27in FHD Monitor                 1      149.99
# 4        141238            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 185705   319666    Lightning Charging Cable                 1       14.95
# 185706   319667       AA Batteries (4-pack)                 2        3.84
# 185707   319668             Vareebadd Phone                 1      400.00
# 185708   319669            Wired Headphones                 1       11.99
# 185709   319670  Bose SoundSport Headphones                 1       99.99
#
#                 Order Date                        Purchase Address  Origem  \
# ...

# %%
VENDAS['Hora'] = VENDAS['Order Date'].dt.hour
VENDAS
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        141234                      iPhone                 1      700.00
# 1        141235    Lightning Charging Cable                 1       14.95
# 2        141236            Wired Headphones                 2       11.99
# 3        141237            27in FHD Monitor                 1      149.99
# 4        141238            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 185705   319666    Lightning Charging Cable                 1       14.95
# 185706   319667       AA Batteries (4-pack)                 2        3.84
# 185707   319668             Vareebadd Phone                 1      400.00
# 185708   319669            Wired Headphones                 1       11.99
# 185709   319670  Bose SoundSport Headphones                 1       99.99
#
#                 Order Date                        Purchase Address  Origem  \
# ...

# %%
VENDAS.groupby('Hora').count()['Order ID']
# Out:
# Hora
# 0      3902
# 1      2347
# 2      1242
# 3       830
# 4       852
# 5      1320
# 6      2481
# 7      4002
# 8      6252
# 9      8740
# 10    10929
# 11    12392
# 12    12573
# 13    12115
# 14    10965
# 15    10159
# 16    10359
# 17    10884
# 18    12263
# 19    12886
# 20    12218
# 21    10905
# 22     8808
# 23     6262
# Name: Order ID, dtype: int64

# %%
xData = [hora for hora, df in VENDAS.groupby('Hora')]
yData = VENDAS.groupby('Hora').count()['Order ID']

plt.plot(xData, yData)

plt.xticks(xData)
plt.title('Vendas por Horário')
plt.ylabel('Quantidade')
plt.xlabel('Horário')

plt.show()

# %%
xData = [hora for hora, df in VENDAS.groupby('Hora')]
yData = VENDAS.groupby('Hora').count()['Order ID']

plt.plot(xData, yData)

plt.xticks(xData)
plt.grid()
plt.title('Vendas por Horário')
plt.ylabel('Quantidade')
plt.xlabel('Horário')

plt.show()

# %% [markdown]
# #### No horário de almoço (entre 11 e 13h) e no fim do expediente (17 a 20h).

# %% [markdown]
# ## 04. Qual é o produto mais vendido? Avalie o motivo de esse produto ser o mais vendido.

# %%
oProdAgrup = VENDAS.groupby('Product')

# %%
oProdAgrup.sum()
# Out:
#                             Quantity Ordered  Price Each     Mes  Faturamento  \
# Product
# 20in Monitor                            4126   450739.02   29319    453818.74
# 27in 4K Gaming Monitor                  6239  2427687.75   44396   2433147.61
# 27in FHD Monitor                        7541  1124625.02   52484   1131074.59
# 34in Ultrawide Monitor                  6192  2346058.26   43258   2352898.08
# AA Batteries (4-pack)                  27615    78942.72  145423    106041.60
# AAA Batteries (4-pack)                 30986    61629.88  146149     92648.14
# Apple Airpods Headphones               15637  2328750.00  109304   2345550.00
# Bose SoundSport Headphones             13430  1329667.02   93918   1342865.70
# Flatscreen TV                           4813  1438200.00   34172   1443900.00
# Google Phone                            5529  3313200.00   38286   3317400.00
# LG Dryer                                 646   387600.00    4383    387600.00
# ...

# %%
qtde = oProdAgrup.sum()['Quantity Ordered']

# %%
prod = [prod for prod, df in VENDAS.groupby('Product')]

# %%
plt.bar(prod, qtde)

plt.xticks(prod, rotation = 'vertical')
plt.title('Vendas por produto')
plt.ylabel('Quantidade')
plt.xlabel('Produto')

plt.show()

# %%
vmed = oProdAgrup.mean()['Price Each']

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

ax1.bar(prod, qtde)
ax2.plot(prod, vmed)

ax1.set_xlabel('Produtos')
ax1.set_ylabel('Quantidade')
ax1.set_xticklabels(prod, rotation = 'vertical')
ax2.set_ylabel('Preço médio')


plt.show()

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

ax1.bar(prod, qtde, color = 'g')
ax2.plot(prod, vmed, color = 'b')

ax1.set_xlabel('Produtos')
ax1.set_ylabel('Quantidade', color = 'g')
ax1.set_xticklabels(prod, rotation = 'vertical')
ax2.set_ylabel('Preço médio', color = 'b')


plt.show()

# %% [markdown]
# #### O produto mais vendido no período é AAA Batteries (4-pack), muito provavelmente devido ao baixo preço.

# %% [markdown]
# ### 05. Quais produtos são geralmente vendidos em conjunto (bundle)?

# %%
VENDAS.head()

# %%
BUNDLE = VENDAS[VENDAS["Order ID"].duplicated(keep = False)] # keep = False marca todas as duplicidades como True
BUNDLE

# %%
BUNDLE['Combinacao'] = BUNDLE.groupby('Order ID').Product.transform(lambda prod: ''.join('|' + prod + '|'))
BUNDLE

# %%
BUNDLE = BUNDLE.sort_values(by = ['Order ID', 'Product'])

# %%
BUNDLE.groupby('Combinacao').count()['Order ID']

# %%
BUNDLE.groupby('Combinacao').count()['Order ID'].sort_values(ascending = False)

# %%
DF = pd.DataFrame()

for i in BUNDLE.Product.unique():
    
    for j in BUNDLE.Product.unique():
        
        a, b = sorted([i, j])
        
        a = "|" + a + "|"
        b = "|" + b + "|"
        
        bundle = a + b
        
        qty = BUNDLE[BUNDLE.Combinacao.map(lambda x : a in x and b in x)]["Order ID"].nunique()
        mean = BUNDLE[BUNDLE.Combinacao.map(lambda x : a in x and b in x)]["Price Each"].astype(float).mean()
            
        if (a != b and qty > 0): DF = DF.append( {"Bundle" : bundle, "Qty" : qty, "Mean" : mean} , ignore_index=True)
        
DF = DF.sort_values(by="Qty", ascending=False).drop_duplicates()

# %%
DF

# %%
ALL_DATA_BUNDLE[ALL_DATA_BUNDLE.Bundle.map(lambda x : "Lightning Charging Cable" in x and "iPhone" in x)]

# %%
import matplotlib.pyplot as plt

# %%
xData = DF.Bundle.values[:10]
yData01 = DF.Qty.values[:10]
yData02 = DF.Mean.values[:10]

plt.figure(figsize=(5,3), dpi=150)

plt.bar(xData, yData01)
plt.plot(xData, yData02)

plt.xticks(xData, rotation="vertical")
# plt.yticks()

plt.title("")
plt.ylabel("")
plt.xlabel("")

plt.show()

# %%
yData

# %%
xData
